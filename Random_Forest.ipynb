# %% [markdown]
# <a href="https://colab.research.google.com/github/Thejeswar03/Breast_cancer_Classification/blob/main/Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing necessary Packages

# %%
! pip install fastbook kaggle dtreeviz
from fastbook import *

import pandas as pd
import matplotlib.pyplot as plt
from pandas.api.types import is_string_dtype, is_numeric_dtype, is_categorical_dtype
from fastai.tabular.all import *
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from dtreeviz.trees import *
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 719 kB 7.4 MB/s
# ...
#      |████████████████████████████████| 72 kB 1.0 MB/s
# ...
#      |████████████████████████████████| 441 kB 12.2 MB/s
# ...
#      |████████████████████████████████| 5.3 MB 69.1 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 68.4 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 56.9 MB/s
# ...
#      |████████████████████████████████| 115 kB 66.7 MB/s
# ...
#      |████████████████████████████████| 163 kB 75.8 MB/s
# ...
#      |████████████████████████████████| 212 kB 81.0 MB/s
# ...
#      |████████████████████████████████| 127 kB 72.7 MB/s
# ...
#      |████████████████████████████████| 115 kB 70.3 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 50.7 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %% [markdown]
# Loading the data file

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-90fb750a-946d-42fe-bb37-d1948191be8a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90fb750a-946d-42fe-bb37-d1948191be8a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('data.csv')

df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df = df.drop('Unnamed: 32', axis = 1)

df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# Dropping Null rows in the Data Frame

# %%
df.dropna()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# Splitting the data into Train and Test data sets

# %%
tt_split=np.random.rand(len(df))>0.9
train_df=df[~tt_split]
test_df=df[tt_split]
len(train_df), len(test_df)
# Out:
# (504, 65)

# %%
dep_var='diagnosis'
cont, cat=cont_cat_split(train_df, 1, dep_var=dep_var)

# %%
cont
# Out:
# ['id',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
cat
# Out:
# []

# %%
procs = [FillMissing, Normalize]
splits = RandomSplitter()(range_of(train_df))
to = TabularPandas(train_df, procs, cat, cont, y_names=dep_var, splits=splits)

# %%
len(to.train), len(to.valid)
# Out:
# (404, 100)

# %%
to.show(3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>radius_mean</th>
#       <th>texture_mean</th>
#       <th>perimeter_mean</th>
#       <th>area_mean</th>
#       <th>smoothness_mean</th>
#       <th>compactness_mean</th>
#       <th>concavity_mean</th>
#       <th>concave points_mean</th>
#       <th>symmetry_mean</th>
#       <th>fractal_dimension_mean</th>
#       <th>radius_se</th>
#       <th>texture_se</th>
#       <th>perimeter_se</th>
#       <th>area_se</th>
#       <th>smoothness_se</th>
#       <th>compactness_se</th>
#       <th>concavity_se</th>
#       <th>concave points_se</th>
#       <th>symmetry_se</th>
#       <th>fractal_dimension_se</th>
#       <th>radius_worst</th>
#       <th>texture_worst</th>
#       <th>perimeter_worst</th>
#       <th>area_worst</th>
#       <th>smoothness_worst</th>
#       <th>compactness_worst</th>
#       <th>concavity_worst</th>
# ...

# %%
xs, y=to.train.xs, to.train.y
valid_xs, valid_y=to.valid.xs, to.valid.y

# %% [markdown]
# #Random Forest Classifier

# %%
def accu(preds, targs): return (preds==targs).mean()
def accur(m, xs, y): return round(accu(m.predict(xs), y), 6)

# %%
def rf(xs, y, n_estimators=40, max_features=0.5,
       min_samples_leaf=5, **kwargs):
    return RandomForestClassifier(n_jobs=-1, n_estimators=n_estimators,
                                max_features=max_features, 
                                min_samples_leaf=min_samples_leaf, 
                                oob_score=True).fit(xs, y)

# %%
m=rf(xs, y)

# %%
accur(m, xs, y), accur(m, valid_xs, valid_y)
# Out:
# (0.980198, 0.94)

# %%
preds=np.stack([t.predict(valid_xs) for t in m.estimators_]);
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# ...

# %%
def accu_preds(preds, valid_y): return ((preds.mean(0)>0.5)==valid_y).mean()

# %%
plt.plot([accu_preds(preds[:i+1], valid_y) for i in range(40)])

# %%
to_test=TabularPandas(test_df, procs, cat, cont, y_names=dep_var)
test_xs, test_y = to_test.train.xs, to_test.train.y

# %%
accu(m.predict(test_xs), test_y)
# Out:
# 0.9230769230769231

# %%
def rf_feat_importance(m, df):
    return pd.DataFrame({'cols': df.columns, 'imp': m.feature_importances_}
                       ).sort_values('imp', ascending=False)

# %%
fi=rf_feat_importance(m, xs)
fi
# Out:
#                        cols       imp
# 23          perimeter_worst  0.251635
# 8       concave points_mean  0.200956
# 28     concave points_worst  0.178194
# 21             radius_worst  0.169428
# 4                 area_mean  0.059416
# 24               area_worst  0.026291
# 22            texture_worst  0.023212
# 26        compactness_worst  0.017423
# 7            concavity_mean  0.012827
# 14                  area_se  0.007807
# 27          concavity_worst  0.006674
# 1               radius_mean  0.006549
# 25         smoothness_worst  0.006046
# 2              texture_mean  0.005521
# 0                        id  0.004124
# 6          compactness_mean  0.004043
# 29           symmetry_worst  0.002825
# 13             perimeter_se  0.002733
# 20     fractal_dimension_se  0.002258
# 15            smoothness_se  0.001960
# 11                radius_se  0.001658
# 18        concave points_se  0.001584
# 3            perimeter_mean  0.001325
# 17             concavity_se  0.001229
# ...

# %%
def plot_fi(fi): return fi.plot('cols', 'imp', 'barh', figsize=(15, 8), legend=False)
plot_fi(fi);

# %%
to_keep=fi[fi.imp>0.005].cols
len(to_keep)
# Out:
# 14

# %%
xs_imp=xs[to_keep]
valid_xs_imp=valid_xs[to_keep]

# %%
m=rf(xs_imp, y)

# %%
accur(m, xs_imp, y), accur(m, valid_xs_imp, valid_y)
# Out:
# (0.977723, 0.96)

# %%
test_xs_imp=test_xs[to_keep]
accu(m.predict(test_xs_imp), test_y)
# Out:
# 0.9230769230769231
